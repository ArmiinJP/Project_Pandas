# %%
import pandas as pd

# %%
titanic = pd.read_csv('train.csv')
t = titanic.set_index(['PassengerId'])
pd.set_option('display.max_rows', None)

# %%
ff = t[t['Cabin'].duplicated(keep=False)]['Cabin'].value_counts()

for i in ff.items():
    print(f'Cabin: {i[0]}, duplicate in {i[1]} times')
    for column in t.columns:
        if column in ['Name', 'Cabin']:
            continue
        percent = round(t[t['Cabin'] == i[0]].fillna(-1)[column].value_counts(normalize=True)*100, 2).max()
        column_value = t[t['Cabin'] == i[0]].fillna(-1)[column].value_counts().sort_values(ascending=False).head(1).index[0]
        print(f'\t\t\t{percent}% tell {column} is {column_value}')
# Out:
# Cabin: C23 C25 C27, duplicate in 4 times
# 			50.0% tell Survived is 0
# 			100.0% tell Pclass is 1
# 			50.0% tell Sex is male
# 			25.0% tell Age is 19.0
# 			75.0% tell SibSp is 3
# 			75.0% tell Parch is 2
# 			100.0% tell Ticket is 19950
# 			100.0% tell Fare is 263.0
# 			100.0% tell Embarked is S
# Cabin: G6, duplicate in 4 times
# 			50.0% tell Survived is 1
# 			100.0% tell Pclass is 3
# 			100.0% tell Sex is female
# 			25.0% tell Age is 4.0
# 			50.0% tell SibSp is 1
# 			75.0% tell Parch is 1
# 			50.0% tell Ticket is PP 9549
# 			50.0% tell Fare is 16.7
# 			100.0% tell Embarked is S
# Cabin: B96 B98, duplicate in 4 times
# 			100.0% tell Survived is 1
# 			100.0% tell Pclass is 1
# 			50.0% tell Sex is male
# 			50.0% tell Age is 36.0
# 			100.0% tell SibSp is 1
# 			100.0% tell Parch is 2
# 			100.0% tell Ticket is 113760
# 			100.0% tell Fare is 120.0
# 			100.0% tell Embarked is S
# Cabin: C22 C26, duplicate in 3 times
# 			66.67% tell Survived is 0
# ...

# %%
ff = t[t['Cabin'].duplicated(keep=False)]['Cabin'].value_counts()

for column in t.columns:
    if column in ['Name', 'Cabin']:
        continue
    for i in ff.items():
        percent = round(t[t['Cabin'] == i[0]].fillna(-1)[column].value_counts(normalize=True)*100, 2).max()
        column_value = t[t['Cabin'] == i[0]].fillna(-1)[column].value_counts().sort_values(ascending=False).head(1).index[0]
        print(f'Cabin: {i[0]}, duplicate in {i[1]} times and {percent}% tell {column} is {column_value}')
    print("----------------------------------------------------------")
# Out:
# Cabin: C23 C25 C27, duplicate in 4 times and 50.0% tell Survived is 0
# Cabin: G6, duplicate in 4 times and 50.0% tell Survived is 1
# Cabin: B96 B98, duplicate in 4 times and 100.0% tell Survived is 1
# Cabin: C22 C26, duplicate in 3 times and 66.67% tell Survived is 0
# Cabin: D, duplicate in 3 times and 66.67% tell Survived is 1
# Cabin: F33, duplicate in 3 times and 100.0% tell Survived is 1
# Cabin: E101, duplicate in 3 times and 100.0% tell Survived is 1
# Cabin: F2, duplicate in 3 times and 66.67% tell Survived is 1
# Cabin: E25, duplicate in 2 times and 100.0% tell Survived is 1
# Cabin: B18, duplicate in 2 times and 100.0% tell Survived is 1
# Cabin: C124, duplicate in 2 times and 100.0% tell Survived is 0
# Cabin: B35, duplicate in 2 times and 100.0% tell Survived is 1
# Cabin: E44, duplicate in 2 times and 50.0% tell Survived is 0
# Cabin: C92, duplicate in 2 times and 100.0% tell Survived is 1
# Cabin: D20, duplicate in 2 times and 100.0% tell Survived is 1
# ...

# %%
ff = t[t['Cabin'].duplicated(keep=False)]['Cabin'].value_counts()

for column in t.columns:
    sum = 0
    if column in ['Name', 'Cabin']:
        continue
    for i in ff.items():
        percent = round(t[t['Cabin'] == i[0]].fillna(-1)[column].value_counts(normalize=True)*100, 2).max()
        column_value = t[t['Cabin'] == i[0]].fillna(-1)[column].value_counts().sort_values(ascending=False).head(1).index[0]
        sum += i[1] * percent

    print(f'{column}:    \t', sum/ff.sum())
    print("----------------------------------------------------------")
# Out:
# Survived:    	 82.52456310679611
# ----------------------------------------------------------
# Pclass:    	 100.0
# ----------------------------------------------------------
# Sex:    	 74.75747572815534
# ----------------------------------------------------------
# Age:    	 48.54339805825243
# ----------------------------------------------------------
# SibSp:    	 94.17485436893205
# ----------------------------------------------------------
# Parch:    	 93.20398058252428
# ----------------------------------------------------------
# Ticket:    	 85.43660194174758
# ----------------------------------------------------------
# Fare:    	 89.32029126213592
# ----------------------------------------------------------
# Embarked:    	 97.08757281553399
# ----------------------------------------------------------
