# %%
import pandas as pd

# %%
titanic = pd.read_csv('train.csv')
t = titanic.set_index(['PassengerId'])
pd.set_option('display.max_rows', None)

# %%
ff = t[t['SibSp'].duplicated(keep=False)]['SibSp'].value_counts()

for i in ff.items():
    print(f'SibSp: {i[0]}, duplicate in {i[1]} times')
    for column in t.columns:
        if column in ['Name', 'SibSp']:
            continue
        percent = round(t[t['SibSp'] == i[0]].fillna(-1)[column].value_counts(normalize=True)*100, 2).max()
        column_value = t[t['SibSp'] == i[0]].fillna(-1)[column].value_counts().sort_values(ascending=False).head(1).index[0]
        print(f'\t\t\t{percent}% tell {column} is {column_value}')
# Out:
# SibSp: 0, duplicate in 608 times
# 			65.46% tell Survived is 0
# 			57.73% tell Pclass is 3
# 			71.38% tell Sex is male
# 			22.53% tell Age is -1.0
# 			88.32% tell Parch is 0
# 			1.15% tell Ticket is 1601
# 			7.07% tell Fare is 8.05
# 			79.28% tell Cabin is -1
# 			72.04% tell Embarked is S
# SibSp: 1, duplicate in 209 times
# 			53.59% tell Survived is 1
# 			39.71% tell Pclass is 3
# 			50.72% tell Sex is female
# 			12.44% tell Age is -1.0
# 			58.85% tell Parch is 0
# 			1.91% tell Ticket is 113760
# 			8.61% tell Fare is 26.0
# 			66.99% tell Cabin is -1
# 			69.38% tell Embarked is S
# SibSp: 2, duplicate in 28 times
# 			53.57% tell Survived is 0
# 			53.57% tell Pclass is 3
# 			53.57% tell Sex is male
# 			14.29% tell Age is 24.0
# 			57.14% tell Parch is 0
# 			10.71% tell Ticket is 2666
# 			10.71% tell Fare is 19.2583
# 			78.57% tell Cabin is -1
# 			67.86% tell Embarked is S
# SibSp: 4, duplicate in 18 times
# 			83.33% tell Survived is 0
# ...

# %%
ff = t[t['SibSp'].duplicated(keep=False)]['SibSp'].value_counts()

for column in t.columns:
    if column in ['Name', 'SibSp']:
        continue
    for i in ff.items():
        percent = round(t[t['SibSp'] == i[0]].fillna(-1)[column].value_counts(normalize=True)*100, 2).max()
        column_value = t[t['SibSp'] == i[0]].fillna(-1)[column].value_counts().sort_values(ascending=False).head(1).index[0]
        print(f'SibSp: {i[0]}, duplicate in {i[1]} times and {percent}% tell {column} is {column_value}')
    print("----------------------------------------------------------")
# Out:
# SibSp: 0, duplicate in 608 times and 65.46% tell Survived is 0
# SibSp: 1, duplicate in 209 times and 53.59% tell Survived is 1
# SibSp: 2, duplicate in 28 times and 53.57% tell Survived is 0
# SibSp: 4, duplicate in 18 times and 83.33% tell Survived is 0
# SibSp: 3, duplicate in 16 times and 75.0% tell Survived is 0
# SibSp: 8, duplicate in 7 times and 100.0% tell Survived is 0
# SibSp: 5, duplicate in 5 times and 100.0% tell Survived is 0
# ----------------------------------------------------------
# SibSp: 0, duplicate in 608 times and 57.73% tell Pclass is 3
# SibSp: 1, duplicate in 209 times and 39.71% tell Pclass is 3
# SibSp: 2, duplicate in 28 times and 53.57% tell Pclass is 3
# SibSp: 4, duplicate in 18 times and 100.0% tell Pclass is 3
# SibSp: 3, duplicate in 16 times and 75.0% tell Pclass is 3
# SibSp: 8, duplicate in 7 times and 100.0% tell Pclass is 3
# SibSp: 5, duplicate in 5 times and 100.0% tell Pclass is 3
# ...

# %%
ff = t[t['SibSp'].duplicated(keep=False)]['SibSp'].value_counts()

for column in t.columns:
    sum = 0
    if column in ['Name', 'SibSp']:
        continue
    for i in ff.items():
        percent = round(t[t['SibSp'] == i[0]].fillna(-1)[column].value_counts(normalize=True)*100, 2).max()
        column_value = t[t['SibSp'] == i[0]].fillna(-1)[column].value_counts().sort_values(ascending=False).head(1).index[0]
        sum += i[1] * percent

    print(f'{column}:    \t', sum/ff.sum())
    print("----------------------------------------------------------")
# Out:
# Survived:    	 63.299539842873166
# ----------------------------------------------------------
# Pclass:    	 55.10571268237934
# ----------------------------------------------------------
# Sex:    	 65.7682603815937
# ----------------------------------------------------------
# Age:    	 20.42466891133558
# ----------------------------------------------------------
# Parch:    	 79.01024691358023
# ----------------------------------------------------------
# Ticket:    	 3.926273849607183
# ----------------------------------------------------------
# Fare:    	 9.537564534231203
# ----------------------------------------------------------
# Cabin:    	 77.10786756453422
# ----------------------------------------------------------
# Embarked:    	 72.2793041526375
# ----------------------------------------------------------
