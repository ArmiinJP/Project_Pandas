# %%
import pandas as pd

# %%
titanic = pd.read_csv('train.csv')
t = titanic.set_index(['PassengerId'])
pd.set_option('display.max_rows', None)

# %%
ff = t[t['Age'].duplicated(keep=False)]['Age'].value_counts()

for i in ff.items():
    print(f'Age: {i[0]}, duplicate in {i[1]} times')
    for column in t.columns:
        if column in ['Name', 'Age']:
            continue
        percent = round(t[t['Age'] == i[0]].fillna(-1)[column].value_counts(normalize=True)*100, 2).max()
        column_value = t[t['Age'] == i[0]].fillna(-1)[column].value_counts().sort_values(ascending=False).head(1).index[0]
        print(f'\t\t\t{percent}% tell {column} is {column_value}')
# Out:
# Age: 24.0, duplicate in 30 times
# 			50.0% tell Survived is 0
# 			43.33% tell Pclass is 3
# 			53.33% tell Sex is female
# 			70.0% tell SibSp is 0
# 			73.33% tell Parch is 0
# 			6.67% tell Ticket is PC 17477
# 			10.0% tell Fare is 13.0
# 			70.0% tell Cabin is -1
# 			76.67% tell Embarked is S
# Age: 22.0, duplicate in 27 times
# 			59.26% tell Survived is 0
# 			74.07% tell Pclass is 3
# 			55.56% tell Sex is male
# 			85.19% tell SibSp is 0
# 			85.19% tell Parch is 0
# 			3.7% tell Ticket is A/5 21171
# 			14.81% tell Fare is 7.25
# 			88.89% tell Cabin is -1
# 			77.78% tell Embarked is S
# Age: 18.0, duplicate in 26 times
# 			65.38% tell Survived is 0
# 			61.54% tell Pclass is 3
# 			50.0% tell Sex is female
# 			69.23% tell SibSp is 0
# 			69.23% tell Parch is 0
# 			3.85% tell Ticket is 345764
# 			7.69% tell Fare is 11.5
# 			84.62% tell Cabin is -1
# 			80.77% tell Embarked is S
# Age: 30.0, duplicate in 25 times
# 			60.0% tell Survived is 0
# ...

# %%
ff = t[t['Age'].duplicated(keep=False)]['Age'].value_counts()

for column in t.columns:
    if column in ['Name', 'Age']:
        continue
    for i in ff.items():
        percent = round(t[t['Age'] == i[0]].fillna(-1)[column].value_counts(normalize=True)*100, 2).max()
        column_value = t[t['Age'] == i[0]].fillna(-1)[column].value_counts().sort_values(ascending=False).head(1).index[0]
        print(f'Age: {i[0]}, duplicate in {i[1]} times and {percent}% tell {column} is {column_value}')
    print("----------------------------------------------------------")
# Out:
# Age: 24.0, duplicate in 30 times and 50.0% tell Survived is 0
# Age: 22.0, duplicate in 27 times and 59.26% tell Survived is 0
# Age: 18.0, duplicate in 26 times and 65.38% tell Survived is 0
# Age: 30.0, duplicate in 25 times and 60.0% tell Survived is 0
# Age: 19.0, duplicate in 25 times and 64.0% tell Survived is 0
# Age: 28.0, duplicate in 25 times and 72.0% tell Survived is 0
# Age: 21.0, duplicate in 24 times and 79.17% tell Survived is 0
# Age: 25.0, duplicate in 23 times and 73.91% tell Survived is 0
# Age: 36.0, duplicate in 22 times and 50.0% tell Survived is 0
# Age: 29.0, duplicate in 20 times and 60.0% tell Survived is 0
# Age: 27.0, duplicate in 18 times and 61.11% tell Survived is 1
# Age: 32.0, duplicate in 18 times and 50.0% tell Survived is 0
# Age: 35.0, duplicate in 18 times and 61.11% tell Survived is 1
# Age: 26.0, duplicate in 18 times and 66.67% tell Survived is 0
# Age: 31.0, duplicate in 17 times and 52.94% tell Survived is 0
# ...

# %%
ff = t[t['Age'].duplicated(keep=False)]['Age'].value_counts()

for column in t.columns:
    sum = 0
    if column in ['Name', 'Age']:
        continue
    for i in ff.items():
        percent = round(t[t['Age'] == i[0]].fillna(-1)[column].value_counts(normalize=True)*100, 2).max()
        column_value = t[t['Age'] == i[0]].fillna(-1)[column].value_counts().sort_values(ascending=False).head(1).index[0]
        sum += i[1] * percent

    print(f'{column}:    \t', sum/ff.sum())
    print("----------------------------------------------------------")
# Out:
# Survived:    	 65.18676217765044
# ----------------------------------------------------------
# Pclass:    	 59.45581661891118
# ----------------------------------------------------------
# Sex:    	 66.1894269340974
# ----------------------------------------------------------
# SibSp:    	 68.33896848137536
# ----------------------------------------------------------
# Parch:    	 78.93985673352434
# ----------------------------------------------------------
# Ticket:    	 11.461704871060173
# ----------------------------------------------------------
# Fare:    	 16.76181948424069
# ----------------------------------------------------------
# Cabin:    	 74.21183381088825
# ----------------------------------------------------------
# Embarked:    	 79.51322349570201
# ----------------------------------------------------------
