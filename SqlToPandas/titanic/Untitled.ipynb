# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib

# %%
titanic = pd.read_csv('train.csv')
tips = titanic.set_index(['PassengerId'])
tips.nunique()
# Out:
# Survived      2
# Pclass        3
# Name        891
# Sex           2
# Age          88
# SibSp         7
# Parch         7
# Ticket      681
# Fare        248
# Cabin       147
# Embarked      3
# dtype: int64

# %%
new1 = tips.groupby(by=['SibSp', 'Parch', 'Sex', 'Survived', 'Pclass']).size().unstack()
new1
# Out:
# Pclass                          1     2      3
# SibSp Parch Sex    Survived
# 0     0     female 0          1.0   3.0   23.0
#                    1         33.0  29.0   37.0
#             male   0         50.0  65.0  232.0
#                    1         25.0   7.0   32.0
#       1     female 0          NaN   NaN    3.0
# ...                           ...   ...    ...
# 4     2     male   1          NaN   NaN    1.0
# 5     2     female 0          NaN   NaN    1.0
#             male   0          NaN   NaN    4.0
# 8     2     female 0          NaN   NaN    3.0
#             male   0          NaN   NaN    4.0
#
# [61 rows x 3 columns]

# %%
sns.relplot(
    data=new1,
    x="count", y="SibSp", col="Survived",
    hue="Survived", style="Survived", size='Survived',
)
matplotlib.pyplot.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 sns.relplot(
#       2     data=new1,
#       3     x="count", y="SibSp", col="Survived",
#       4     hue="Survived", style="Survived", size='Survived',
#       5 )
#       6 matplotlib.pyplot.show()
#
# File ~/Project/Project_Pandas/.venv/lib/python3.9/site-packages/seaborn/relational.py:862, in relplot(data, x, y, hue, size, style, units, row, col, col_wrap, row_order, col_order, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, dashes, style_order, legend, kind, height, aspect, facet_kws, **kwargs)
#     859     kwargs.pop("ax")
#     861 # Use the full dataset to map the semantics
# --> 862 p = plotter(
#     863     data=data,
#     864     variables=plotter.get_semantics(locals()),
#     865     legend=legend,
#     866 )
# ...

# %%
#importing library
import seaborn as sns
#setting theme
sns.set_theme(style="darkgrid")
#importing dataset
#titanic = sns.load_dataset(tip)
#plotting chart
sns.pairplot(tips, hue="Survived")
plt.show()
# Out:
# /home/armin/Project/Project_Pandas/.venv/lib/python3.9/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[59], line 9
#       5 #importing dataset
#       6 #titanic = sns.load_dataset(tip)
#       7 #plotting chart
#       8 sns.pairplot(tips, hue="Survived")
# ----> 9 plt.show()
#
# NameError: name 'plt' is not defined
