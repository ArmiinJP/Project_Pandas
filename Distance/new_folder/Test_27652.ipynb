# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import numpy as np
import sklearn as sk
import math

# %%
dist = pd.read_csv('../dist_data.csv', sep=';')

# %%
dist_clean = dist[dist['dist'] != "[[], []]"]

# %%
x = dist_clean.iloc[:, :-1].values
y = dist_clean.iloc[:, 1].values

# %%
# from sklearn.model_selection import train_test_split
# x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.30)

# %%
def clean_sample(sample):
    sample_list = sample[0].replace(', [', '; [').split(';')
    sample_x = sample_list[0]
    sample_Px = sample_list[1]

    sample_x_list = []
    sample_Px_list = []
    
    for x in sample_x.split(','):
        sample_x_list.append(x.replace(' ', '').replace('[', '').replace(']', ''))
    for Px in sample_Px.split(','):
        sample_Px_list.append(Px.replace(' ', '').replace('[', '').replace(']', ''))

    dict_sample = {}
    for i in range(len(sample_x_list)):
        dict_sample[sample_x_list[i]] = sample_Px_list[i]
    return dict_sample

# %%
for i in range(len(y)):
    if( y[i] == 27652 ):
        print(clean_sample(x[i]))
# Out:
# {'443': '0.9979888599145809', '16390': '0.0005027850213547747', '23089': '0.0005027850213547747', '34956': '0.0005027850213547747', '50550': '0.0005027850213547747'}
# {'443': '0.9965689393965738', '13271': '0.0008577651508565481', '16844': '0.0008577651508565481', '27757': '0.0008577651508565481', '54867': '0.0008577651508565481'}
# {'443': '0.9964938281900004', '10199': '0.0003506171809999602', '10851': '0.0003506171809999602', '18510': '0.0003506171809999602', '23140': '0.0003506171809999602', '23295': '0.0003506171809999602', '30682': '0.0003506171809999602', '31505': '0.0003506171809999602', '45713': '0.0003506171809999602', '52623': '0.0003506171809999602', '59550': '0.0003506171809999602'}
# {'443': '0.9999955683077238', '47292': '4.431692276111967e-06'}
# {'443': '1.0'}
# {'443': '1.0'}
# {'443': '0.9994069647977509', '50489': '0.000593035202249046'}
# {'443': '0.9975625703025542', '45755': '0.0012187148487229022', '48882': '0.0012187148487229022'}
# {'27695': '1.0'}
# {'443': '1.0'}
# {'443': '1.0'}
# {'443': '0.9973758728403882', '24328': '0.0010805229480754489', '18171': '0.0007718021057681778', '26721': '0.0007718021057681778'}
# {'443': '0.9988243748401389', '22958': '0.00039187505328706386', '41620': '0.00039187505328706386', '43775': '0.00039187505328706386'}
# {'443': '0.9999383209148804', '13412': '6.167908511955466e-05'}
# {'443': '0.9983817036287016', '64403': '0.0016182963712984204'}
# {'31981': '1.0'}
# {'23': '1.0'}
# {'443': '0.9998676039294617', '19956': '3.3099017634575125e-05', '46475': '3.3099017634575125e-05', '46476': '3.3099017634575125e-05', '63295': '3.3099017634575125e-05'}
# {'443': '0.9985886548832065', '21459': '0.0014113451167935764'}
# {'443': '0.9956918132808589', '14032': '0.0021540933595705788', '34218': '0.0021540933595705788'}
# {'443': '1.0'}
# {'443': '1.0'}
# {'443': '0.
}
# {'443': '1.0'}
# {'443': '1.0'}
# {'443': '1.0'}
# {'443': '0.9971310151295566', '44995': '0.0019126565802955757', '43206': '0.0009563282901477878'}
# {'443': '0.9969619267297908', '22941': '0.0022757218900957164', '52310': '0.0007623513801135491'}
# {'443': '0.9997028468078921', '63439': '0.00029715319210793246'}
# {'443': '0.9960943066602628', '15565': '0.0009764233349343158', '19504': '0.0009764233349343158', '25244': '0.0009764233349343158', '63567': '0.0009764233349343158'}
# {'443': '0.9994131694291509', '39128': '0.00020392778216598705', '14082': '0.00016566685950432632', '25684': '7.241197639291286e-05', '40018': '7.241197639291286e-05', '55155': '7.241197639291286e-05'}
# {'443': '0.9977610961888209', '36409': '0.0007463012703930184', '30376': '0.0004975341802620122', '51473': '0.0004975341802620122', '64139': '0.0004975341802620122'}
# {'443': '0.9999818950077062', '30606': '9.052496146908997e-06', '61553': '9.052496146908997e-06'}
# {'443': '0.9988815839189904', '13035': '0.0002796040202523993', '13442': '0.0002796040202523993', '24938': '0.0002796040202523993', '34103': '0.0002796040202523993'}
# {'443': '0.9988358007016661', '31317': '0.0011641992983339364'}
# {'443': '0.9999669240140082', '17561': '5.880175287437301e-06', '25525': '5.439162140879504e-06', '26622': '5.439162140879504e-06', '38008': '5.439162140879504e-06', '39676': '5.439162140879504e-06', '51702': '5.439162140879504e-06'}
# {'443': '1.0'}
# {'443': '0.9971502071876396', '19430': '0.0014248964061801994', '57126': '0.0014248964061801994'}
# {'443': '0.9998429804928207', '24725': '2.100595413770033e-05', '18993': '1.9430507577372808e-05', '25342': '1.9430507577372808e-05', '28117': '1.9430507577372808e-05', '36616': '1.9430507577372808e-05', '53034': '1.9430507577372808e-05', '55355': '1.9430507577372808e-05', '62811': '1.9430507577372808e-05'}
# {'443': '0.9980748348047079', '39157': '0.0007169868211986324', '12377': '0.00043700068850187964', '44968': '0.00025705922853051745', '49398': '0.00025705922853051745', '50034': '0.00025705922853051745'}
# {'443': '0.9786844033939313', '35390': '0.021315596606068746'}
# {'443': '1.0'}
# {'443': '0.99817678904628', '31546': '0.0006077369845733358', '33906': '0.0006077369845733358', '56070': '0.0006077369845733358'}
# {'443': '0.9980236494381423', '44560': '0.0009881752809288847', '50823': '0.0009881752809288847'}
# {'443': '1.0'}
# {'443': '0.9987026920892267', '46409': '0.0012973079107732655'}
# {'443': '0.9993421959100586', '16765': '0.0006578040899413754'}
# {'443': '1.0'}
# {'443': '0.9980488233613851', '28311': '0.0006503922128716134', '47590': '0.0006503922128716134', '50425': '0.0006503922128716134'}
# {'443': '1.0'}

# %%
n27652 = 0
n27321 = 0
for i in range(len(x)):
    tmp_dict = clean_sample(x[i])
    if tmp_dict.get('443') is not None:
        if float(tmp_dict.get('443')) > 0.99 and float(tmp_dict.get('443')) < 1:
            if y[i] == 27652:
                n27652 += 1
            elif y[i] == 27321:
                n27321 += 1
            else:
                pass
            #print(clean_sample(x[i]))

print(n27652)
print(n27321)
# Out:
# 46
# 56
