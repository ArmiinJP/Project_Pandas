# %%
import pandas as pd

# %%
titanic = pd.read_csv('train.csv')
t = titanic.set_index(['PassengerId'])

# %%
titanic.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
sns.catplot(x ="Sex", hue ="Survived", kind ="count", data = t)
# Out:
# /home/arminjp/Documents/Project/pandas/.venv/lib/python3.8/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.catplot(x ="Embarked", hue ="Survived", kind ="count", data = t)
# Out:
# /home/arminjp/Documents/Project/pandas/.venv/lib/python3.8/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.catplot(x ="SibSp", hue ="Survived", kind ="count", data = t, height=5, aspect=2)
# Out:
# /home/arminjp/Documents/Project/pandas/.venv/lib/python3.8/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# Group the dataset by Pclass and Survived and then unstack them
group = titanic.groupby(['Pclass', 'Survived'])
pclass_survived = group.size().unstack()
pclass_survived
sns.catplot(x ="Pclass", y='Survived', data = pclass_survived)
# Heatmap - Color encoded 2D representation of data.
#sns.heatmap(pclass_survived, annot = True, fmt ="d")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[42], line 5
#       3 pclass_survived = group.size().unstack()
#       4 pclass_survived
# ----> 5 sns.catplot(x ="Pclass", y='Survived', data = pclass_survived)
#       6 # Heatmap - Color encoded 2D representation of data.
#       7 #sns.heatmap(pclass_survived, annot = True, fmt ="d")
#
# File ~/Documents/Project/pandas/.venv/lib/python3.8/site-packages/seaborn/categorical.py:3031, in catplot(data, x, y, hue, row, col, col_wrap, estimator, errorbar, n_boot, units, seed, order, hue_order, row_order, col_order, height, aspect, kind, native_scale, formatter, orient, color, palette, hue_norm, legend, legend_out, sharex, sharey, margin_titles, facet_kws, ci, **kwargs)
#    3028 refactored_kinds = ["strip", "swarm"]
#    3029 if kind in refactored_kinds:
# -> 3031     p = _CategoricalFacetPlotter(
# ...

# %%
t.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 891 entries, 1 to 891
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Name      891 non-null    object
#  3   Sex       891 non-null    object
#  4   Age       714 non-null    float64
#  5   SibSp     891 non-null    int64
#  6   Parch     891 non-null    int64
#  7   Ticket    891 non-null    object
#  8   Fare      891 non-null    float64
#  9   Cabin     204 non-null    object
#  10  Embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 83.5+ KB

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#sns.displot(t['Survived'], bins=2, kde=False)


# importing packages 
import seaborn as sns 
  

sns.histplot(x="PassengerId", y="Sex", data=t)
#sns.set_style("dark")
#sns.despine()

plt.title('Title using Matplotlib Function')

#plt.xlim(555)

plt.show()
